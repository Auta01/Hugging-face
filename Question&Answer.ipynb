# %% [markdown]
# <a href="https://colab.research.google.com/github/Auta01/Hugging-face/blob/main/Question%26Answer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer

model_name= 'bert-large-uncased-whole-word-masking-finetuned-squad'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForQuestionAnswering.from_pretrained(model_name)

# %%
context = '''I am Auta from kontagora. my interest include programming and cricket i have created course on hugging face.yes Ai is trending and we all are a part of it .Artificial intelligence(ai) is transforming the world by enabling to learn, adapt, and perform tasks  that typically require human intelligence.'''

question = 'where auta is based'

# %%
inputs = tokenizer(question, context, return_tensors='pt')

output = model(**inputs)
#Extract the start and end score
start_score  =output.start_logits
end_score = output.end_logits

#Get the most likely start and end position
start_index = start_score.argmax()
end_index = end_score.argmax()

#Convert token ids back to word
answer_tokens = inputs['input_ids'][0][start_index:end_index +1]
answer = tokenizer.decode(answer_tokens,skip_special_tokens=True)

print(f'Answer: {answer}')
